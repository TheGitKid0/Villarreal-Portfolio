# %%
from population import *
import matplotlib.pyplot as plt

# simulation 1: Thanos wipes out half the population in 2025
results.plot(label='model', color='purple')
plt.xlabel("Year")
plt.ylabel("Population (Billions)")
# Out:
# Time
# 2000    6.003271
# 2001    6.003458
# 2002    6.003646
# 2003    6.003834
# 2004    6.004023
#           ...
# 2096    6.024102
# 2097    6.024352
# 2098    6.024603
# 2099    6.024855
# 2100    6.110408
# Name: Quantity, Length: 101, dtype: float64
# Text(0, 0.5, 'Population (Billions)')

# %% [markdown]
# As observed from the model, we see that Thanos has snapped the population of the world in half in the year 2025.
#
# (1) How long would it take the population to recover?
#
# We see from our simulation that the population starts recovering right after the snap. However, it is only around the year 2070 where the population catches up to that of the pre-snapped world.
#
# (2) How might carrying capacity and maximum growth rate (as parameters) be affected by such a change?
#
# We believe that with our model, the maximum growth/carrying capacity rate will not change because humaninity kept growing despite such a loss.

# %%
# simulation 2: Thanos wipes out half the population in 2025 but they come back in 2030
results2.plot(label='model', color='purple')
plt.xlabel("Year")
plt.ylabel("Population (Billions)")
# Out:
# Text(0, 0.5, 'Population (Billions)')

# %% [markdown]
# Another method to reduce suffering that does not need to be the random death of half humanity can be a yearly snap that kills off a certain amount of people. This is better for humanity because instead of many people dying from one event, there will be yearly events so that, eventually, it can be interperated as simply tradition. Also, the problem with thanos is that even if you get rid of half the population one year, the remaining half will still recover and overpopulate in a number of years. With our solution, this will be solved.

# %%
# simulation 3: Yearly Sacrfices
results3.plot(label='model', color='purple')
plt.xlabel("Year")
plt.ylabel("Population (Billions)")
# Out:
# Text(0, 0.5, 'Population (Billions)')

# %% [markdown]
# In the example above, we see that instead from our strategy of yearly 'snappenings,' we have achieved a profound level of population stability for the entire 21st century. (killing off ~ 85 million sacrifices/yr)
#
# The only apparent issue is that somehow, with the way the simulation code was set up, there seems to be an inaccurate leap in population for the final data point, likely to be an issue in iteration.
